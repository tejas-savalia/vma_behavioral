# %%
import numpy as np
import scipy.stats as stat
import matplotlib.pyplot as plt
import seaborn as sns
import pickle
import pandas as pd

# %%
errors = pd.read_csv('Curvature_Errors.csv')

# %%
def exp_func_sudden(b, lamb):
    trials = 640
    errors = np.zeros(trials)
    for t in range(trials-1):
        errors[t+1] = 0.2*np.exp(-lamb*(t-1)) 
    return errors

#def exp_func_sudden(b, lamb):
#    trials = 640
#    errors = np.zeros(trials)
#    errors[0] = 1/9.0
#    for t in range(trials-1):
#        if t%
#        errors[t+1] = (b)*np.exp(-lamb*(t-1)) 
#    return errors

# %%
plt.plot(exp_func_sudden(1, 0.006))

# %%
# Out:
# 0.1111111111111111
